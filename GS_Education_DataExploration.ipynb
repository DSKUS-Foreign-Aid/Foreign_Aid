# %% [markdown]
# <h1> Gerardo Sandoval's Data Exploration </h1>

# %%
import AidUtilities as utils

# %%
import pandas as pd

# %% [markdown]
# Start of Data Exploration
# Let's start with Education Data.
#
# # Education Data

# %%
path = '/home/gsandoval/Documents/Classes/depaul/Korea/Data/WorldBank_Education/education_data.txt'
ed_data = pd.read_csv(path, sep='\t')

# %%
ed_data.head(2)
# Out:
#                                          Series Name  Series Code  \
# 0  Adjusted net enrollment rate, primary (% of pr...  SE.PRM.TENR
# 1  Adjusted net enrollment rate, primary (% of pr...  SE.PRM.TENR
#
#   Country Name Country Code 1971 [YR1971] 1972 [YR1972] 1973 [YR1973]  \
# 0      Bolivia          BOL            ..            ..            ..
# 1   Costa Rica          CRI            ..      87.99677      89.38068
#
#   1974 [YR1974] 1975 [YR1975] 1976 [YR1976]  ... 2011 [YR2011] 2012 [YR2012]  \
# 0            ..            ..            ..  ...      91.85201      88.39177
# 1            ..      90.45446      92.63459  ...      99.43417      99.46534
#
#   2013 [YR2013] 2014 [YR2014] 2015 [YR2015] 2016 [YR2016] 2017 [YR2017]  \
# 0       88.0242      87.94434      88.70123      89.84267      91.48686
# 1      98.89928      97.21585      97.81775      98.36736      96.55127
#
#   2018 [YR2018] 2019 [YR2019] 2020 [YR2020]
# 0      93.18324            ..            ..
# ...

# %%
# get Series Names
def clean_col_names(df):
    new_col_names = []
    for col in df.columns:
        if 'YR' in col:
            year, _ = col.split(' ')
            new_col_names.append(year)
        else:
            new_col_names.append(col.replace(' ', '_'))
    df.columns = new_col_names
    return df

# %%
ed_data = clean_col_names(ed_data)

# %%
ed_data.tail(10)
# Out:
#                                            Series_Name        Series_Code  \
# 510  Literacy rate, youth total (% of people ages 1...  SE.ADT.1524.LT.ZS
# 511  Literacy rate, youth total (% of people ages 1...  SE.ADT.1524.LT.ZS
# 512  Literacy rate, youth total (% of people ages 1...  SE.ADT.1524.LT.ZS
# 513  Literacy rate, youth total (% of people ages 1...  SE.ADT.1524.LT.ZS
# 514  Literacy rate, youth total (% of people ages 1...  SE.ADT.1524.LT.ZS
# 515  Literacy rate, youth total (% of people ages 1...  SE.ADT.1524.LT.ZS
# 516  Literacy rate, youth total (% of people ages 1...  SE.ADT.1524.LT.ZS
# 517  Literacy rate, youth total (% of people ages 1...  SE.ADT.1524.LT.ZS
# 518  Literacy rate, youth total (% of people ages 1...  SE.ADT.1524.LT.ZS
# 519  Literacy rate, youth total (% of people ages 1...  SE.ADT.1524.LT.ZS
#
#     Country_Name Country_Code 1971 1972 1973 1974 1975 1976  ...  \
# 510        Chile          CHL   ..   ..   ..   ..   ..   ..  ...
# ...

# %%
series_names = ed_data.Series_Name.unique()
country_names = ed_data.Country_Code.unique()

# %%
print(series_names)
print(country_names)
# Out:
# ['Adjusted net enrollment rate, primary (% of primary school age children)'
#  'Adjusted net enrollment rate, primary, female (% of primary school age children)'
#  'Adjusted net enrollment rate, primary, male (% of primary school age children)'
#  'Adolescents out of school (% of lower secondary school age)'
#  'Adolescents out of school, male (% of male lower secondary school age)'
#  'Adolescents out of school, female (% of female lower secondary school age)'
#  'Children out of school, primary'
#  'Compulsory education, duration (years)'
#  'Current education expenditure, primary (% of total expenditure in primary public institutions)'
#  'Current education expenditure, secondary (% of total expenditure in secondary public institutions)'
#  'Current education expenditure, tertiary (% of total expenditure in tertiary public institutions)'
#  'Current education expenditure, total (% of total expenditure in public institutions)'
# ...

# %%
def rename_series(series_names):
    new_series_names = []
    for series in series_names:
        print(series)
        new_name = input('Enter New Name')
        new_series_names.append(new_name)

# %%
print(new_series_names)
# Out:
# ['Primary_Pct_Enrolled', 'Primary_Pct_Female_Enrolled', 'Primary_Pct_Male_Enrolled', 'Pct_Secondary_Truent', 'Pct_Male_Secondary_Truent', 'Pct_Female_Seconday_Truent', 'Primary_Truent', 'Yrs_Req_Edu', 'Pct_Edu_Expenditure', 'Pct_Secondary_Expenditure', 'Pct_Tertiary_Expenditure', 'Pct_Edu_Expenditure', 'Cum_Pct_wBachelors', 'Pct_Primary_Govt_Expenditure', 'Pct_Secondary_Govt_Expenditure', 'Pct_Tertiary_Govt_Expenditure', 'Pct_GDP_Edu', 'Pct_Govt_Expenditure', 'Govt_Expenditure_perStudent', 'Govt_Expenditure_perStudent_Secondary', 'Govt_Expenditure_perStudent_Tertiary', 'Pct_Pop_Literate', 'Youth_Lit_rate', 'Pct_Males_Literate', 'Pct_Females_Literate', '']

# %%
# Reinstantiate here to correct errors
new_series_names = ['Primary_Pct_Enrolled', 'Primary_Pct_Female_Enrolled', 'Primary_Pct_Male_Enrolled', 
                    'Pct_Secondary_Truent', 'Pct_Male_Secondary_Truent', 'Pct_Female_Seconday_Truent', 
                    'Primary_Truent', 'Yrs_Req_Edu', 'Pct_Edu_Expenditure', 'Pct_Secondary_Expenditure', 
                    'Pct_Tertiary_Expenditure', 'Pct_Edu_Expenditure', 'Cum_Pct_wBachelors', 
                    'Pct_Primary_Govt_Expenditure', 'Pct_Secondary_Govt_Expenditure', 'Pct_Tertiary_Govt_Expenditure', 
                    'Pct_GDP_Edu', 'Pct_Govt_Expenditure', 'Govt_Expenditure_perStudent', 
                    'Govt_Expenditure_perStudent_Secondary', 'Govt_Expenditure_perStudent_Tertiary', 
                    'Pct_Pop_Literate', 'Youth_Lit_rate', 'Pct_Males_Literate', 'Pct_Females_Literate', 'Youth_Lit_Rate']
